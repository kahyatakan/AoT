# %%
import sympy as sp
sp.init_printing()
from aot import simplified_taylor
simplified_taylor
# Out:
#                                                                                ↪
# ⎛                                             ⎛                              ⎛ ↪
# ⎝-2⋅a₁⋅(a₁ - x₁) - 2⋅a₂⋅(a₂ - x₂) + (a₁ - x₁)⋅⎝2⋅a₁⋅a₂⋅(a₂ - x₂) + (a₁ - x₁)⋅⎝ ↪
#
# ↪                                                                              ↪
# ↪     2    ⎞⎞             ⎛                              ⎛    2    ⎞⎞    ⎞  a₁ ↪
# ↪ 2⋅a₁  + 1⎠⎠ + (a₂ - x₂)⋅⎝2⋅a₁⋅a₂⋅(a₁ - x₁) + (a₂ - x₂)⋅⎝2⋅a₂  + 1⎠⎠ + 1⎠⋅ℯ   ↪
#
# ↪ 2     2
# ↪   + a₂
# ↪
